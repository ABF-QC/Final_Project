# %% [markdown]
# ---
# #
# ---
#
# In this notebook,
#
# 1.

# %% [markdown]
# ### Importing necessary libraries

# %%
import os
import glob

import pandas as pd
import numpy as np

from geopy import distance

from id_station import stn_id

# %% [markdown]
# ### Define files

# %%
stn_inventory = '../data/ECCC/Station_Inventory_EN_AdminRegion.csv'

# %%
admin_region = ['Montréal']

data_dir = '../data/ECCC/daily'

filename = 'climate_daily_QC_'

frequency = 'DLY'

out_dir = '../data/ECCC/processed/daily'

outfile = os.path.join(out_dir, 'daily_processed.csv')

# %% [raw]
# admin_region = ['Montréal']
#
# data_dir = '../data/ECCC/monthly/'
#
# filename = 'climate_monthly_QC_'
#
# frequency = 'MLY'
#
# out_dir = '../data/ECCC/processed/monthly/'
#
# outfile = os.path.join(out_dir, 'monthly_processed.csv')

# %% [markdown]
# ### Define variables

# %% [markdown]
# **Daily**

# %%
Tmax = 'Max Temp (°C)'
Tmin =  'Min Temp (°C)' 
Tmean = 'Mean Temp (°C)'

cols = ['Max Temp (°C)', 'Max Temp Flag', 'Min Temp (°C)', 'Min Temp Flag',
       'Mean Temp (°C)', 'Mean Temp Flag', 'Heat Deg Days (°C)',
       'Heat Deg Days Flag', 'Cool Deg Days (°C)', 'Cool Deg Days Flag',
       'Total Rain (mm)', 'Total Rain Flag', 'Total Snow (cm)',
       'Total Snow Flag', 'Total Precip (mm)', 'Total Precip Flag',
       'Snow on Grnd (cm)', 'Snow on Grnd Flag', 'Dir of Max Gust (10s deg)',
       'Dir of Max Gust Flag', 'Spd of Max Gust (km/h)',
       'Spd of Max Gust Flag']

# %% [markdown]
# **Monthly**

# %% [raw]
# Tmax = 'Tm'
# Tmin =  'Tx'
# Tmean = 'Tn'
#
# cols = ['Tm', 'DwTm', 'D', 'Tx', 'DwTx', 'Tn', 'DwTn', 'S',
#        'DwS', 'S%N', 'P', 'DwP', 'P%N', 'S_G', 'Pd', 'BS', 'DwBS', 'BS%',
#        'HDD', 'CDD']

# %% [markdown]
# ### Read Station Inventory file

# %%
stns = pd.read_csv(stn_inventory)
stns.head()
# Out:
#                 Name Province Climate ID  Station ID   WMO ID TC ID  \
# 0  BARRIERE STONEHAM   QUEBEC    7010478        5205      NaN   NaN
# 1  BARRIERE TOURILLI   QUEBEC    7010480        5206      NaN   NaN
# 2           BEAUPORT   QUEBEC    7010565       27803  71578.0   XBO
# 3           BEAUPORT   QUEBEC    7010566        5207      NaN   NaN
# 4      BERTHIERVILLE   QUEBEC    7010720        5208      NaN   NaN
#
#    Latitude (Decimal Degrees)  Longitude (Decimal Degrees)   Latitude  \
# 0                       47.17                       -71.25  471000000
# 1                       47.17                       -71.62  471000000
# 2                       46.84                       -71.20  465013000
# 3                       46.88                       -71.20  465300000
# 4                       46.05                       -73.18  460300000
#
#    Longitude  ...  First Year  Last Year  HLY First Year  HLY Last Year  \
# 0 -711500000  ...        1963       1976             NaN            NaN
# 1 -713700000  ...        1949       1960             NaN            NaN
# 2 -711150000  ...        1999       2025          1999.0         2024.0
# 3 -711200000  ...        1982       1985             NaN            NaN
# 4 -731100000  ...        1919       1995             NaN            NaN
#
#    DLY First Year  DLY Last Year  MLY First Year  MLY Last Year  \
# 0          1963.0         1976.0          1963.0         1976.0
# 1          1949.0         1960.0          1949.0         1960.0
# 2          1999.0         2025.0             NaN            NaN
# 3          1982.0         1985.0          1982.0         1985.0
# 4          1919.0         1995.0          1919.0         1995.0
#
#                geometry               admin
# 0  POINT (-71.25 47.17)  Capitale-Nationale
# 1  POINT (-71.62 47.17)  Capitale-Nationale
# 2   POINT (-71.2 46.84)  Capitale-Nationale
# 3   POINT (-71.2 46.88)  Capitale-Nationale
# 4  POINT (-73.18 46.05)          Lanaudière
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Keep only stations within the desired administrative region

# %%
stns = stns[stns['admin'].isin(admin_region)]
stns
# Out:
#                                        Name Province Climate ID  Station ID  \
# 160                             COTE ST LUC   QUEBEC    7021945        5343
# 217                                LA SALLE   QUEBEC    7024118        5391
# 220                       LAVAL DES RAPIDES   QUEBEC    7024256        5394
# 226                       MACDONALD COLLEGE   QUEBEC    7024400        5400
# 234                                MCTAVISH   QUEBEC    7024745       10761
# 239         MOBILE UPPER AIR STATION-QUEBEC   QUEBEC    7025000       47888
# 242                         MONTREAL ADAC A   QUEBEC    7025228        8343
# 245  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A   QUEBEC    7025250        5415
# 246                         MONTREAL INTL A   QUEBEC    7025251       51157
# 247                            MONTREAL-EST   QUEBEC    7025252       26855
# 248                        MONTREAL JAR BOT   QUEBEC    7025257        5416
# 249                   MONTREAL JEAN BREBEUF   QUEBEC    7025260        5417
# 250                     MONTREAL LAFONTAINE   QUEBEC    7025267        5418
# 251                         MONTREAL LOYOLA   QUEBEC    7025270        5419
# 252                         MONTREAL MCGILL   QUEBEC    7025280        5420
# 253                     MONTREAL PERSILLIER   QUEBEC    7025315        5421
# 268                           POINTE CLAIRE   QUEBEC    7026073        5435
# 270                          POSTE SARAGUAY   QUEBEC    7026213        5436
# 275                    RIVIERE DES PRAIRIES   QUEBEC    7026612        5441
# 286                    STE ANNE DE BELLEVUE   QUEBEC    7026839        5449
# 311                           STE GENEVIEVE   QUEBEC    7027280        5484
# 330                    ST LAURENT (COLLEGE)   QUEBEC    7027440        5499
# 396                      COTE-STE-CATHERINE   QUEBEC    702A9MD       10949
# 401                  STE-ANNE-DE-BELLEVUE 1   QUEBEC    702FHL8       10873
# 412    MONTREAL/PIERRE ELLIOTT TRUDEAU INTL   QUEBEC    702S006       30165
#
#       WMO ID TC ID  Latitude (Decimal Degrees)  Longitude (Decimal Degrees)  \
# 160      NaN   NaN                       45.45                       -73.67
# 217      NaN   NaN                       45.43                       -73.62
# 220      NaN   NaN                       45.53                       -73.70
# 226      NaN   NaN                       45.42                       -73.93
# 234  71612.0   WTA                       45.50                       -73.58
# 239  71054.0   EUQ                       45.43                       -73.93
# 242      NaN   NaN                       45.48                       -73.55
# 245  71627.0   YUL                       45.47                       -73.75
# 246  71627.0   YUL                       45.47                       -73.74
# 247      NaN   WPQ                       45.63                       -73.55
# 248      NaN   NaN                       45.57                       -73.55
# 249      NaN   NaN                       45.50                       -73.62
# 250      NaN   NaN                       45.52                       -73.57
# 251      NaN   NaN                       45.47                       -73.63
# 252      NaN   NaN                       45.50                       -73.58
# 253      NaN   NaN                       45.54                       -73.69
# 268      NaN   NaN                       45.47                       -73.80
# 270      NaN   NaN                       45.50                       -73.75
# 275      NaN   NaN                       45.70                       -73.50
# 286      NaN   NaN                       45.43                       -73.93
# 311      NaN   NaN                       45.50                       -73.85
# 330      NaN   NaN                       45.52                       -73.67
# 396      NaN   WCS                       45.42                       -73.57
# 401  71377.0   WVQ                       45.43                       -73.93
# 412  71183.0   WTQ                       45.47                       -73.74
#
#       Latitude  Longitude  ...  First Year  Last Year  HLY First Year  \
# 160  452700000 -734000000  ...        1960       1963             NaN
# 217  452600000 -733700000  ...        1973       1983             NaN
# 220  453200000 -734200000  ...        1965       1976             NaN
# 226  452500000 -735600000  ...        1906       1976             NaN
# 234  453017070 -733445000  ...        1994       2025          1994.0
# 239  452536000 -735544040  ...        2014       2021          2014.0
# 242  452900000 -733300000  ...        1974       1976          1974.0
# 245  452800000 -734500000  ...        1941       2013          1953.0
# 246  452814000 -734427000  ...        2013       2025          2013.0
# 247  453805000 -733311000  ...        1994       2008          1994.0
# 248  453400000 -733300000  ...        1948       1989             NaN
# 249  453000000 -733700000  ...        1956       1985             NaN
# 250  453100000 -733400000  ...        1971       1992             NaN
# 251  452800000 -733800000  ...        1964       1964             NaN
# 252  453000000 -733500000  ...        1871       1993             NaN
# 253  453221700 -734131700  ...        1948       1950             NaN
# 268  452800000 -734800000  ...        1973       1985             NaN
# 270  453000000 -734500000  ...        1973       1982             NaN
# 275  454200000 -733000000  ...        1973       2024             NaN
# 286  452600000 -735600000  ...        1969       1992             NaN
# 311  453000000 -735100000  ...        1952       2023             NaN
# 330  453100000 -734000000  ...        1931       1967             NaN
# 396  452500000 -733400000  ...        1994       1995          1994.0
# 401  452538000 -735545000  ...        1993       2025          1994.0
# 412  452804000 -734430000  ...        2002       2025          2008.0
#
#      HLY Last Year  DLY First Year  DLY Last Year  MLY First Year  \
# 160            NaN          1960.0         1963.0          1960.0
# 217            NaN          1973.0         1983.0          1973.0
# 220            NaN          1965.0         1976.0          1965.0
# 226            NaN          1906.0         1976.0          1906.0
# 234         2024.0          1994.0         2025.0          1994.0
# 239         2021.0          2017.0         2021.0             NaN
# 242         1976.0             NaN            NaN             NaN
# 245         2013.0          1941.0         2013.0          1941.0
# 246         2024.0          2013.0         2025.0             NaN
# 247         2008.0          1994.0         2008.0             NaN
# 248            NaN          1948.0         1989.0          1948.0
# 249            NaN          1956.0         1985.0          1956.0
# 250            NaN          1971.0         1992.0          1971.0
# 251            NaN          1964.0         1964.0          1964.0
# 252            NaN          1871.0         1993.0          1871.0
# 253            NaN          1948.0         1950.0          1948.0
# 268            NaN          1973.0         1985.0          1973.0
# 270            NaN          1973.0         1982.0          1973.0
# 275            NaN          1973.0         2024.0          1973.0
# 286            NaN          1969.0         1992.0          1969.0
# 311            NaN          1952.0         2023.0          1952.0
# 330            NaN          1931.0         1967.0          1931.0
# 396         1995.0             NaN            NaN             NaN
# 401         2024.0          1993.0         2025.0             NaN
# 412         2024.0          2002.0         2025.0             NaN
#
#      MLY Last Year              geometry     admin
# 160         1963.0  POINT (-73.67 45.45)  Montréal
# 217         1983.0  POINT (-73.62 45.43)  Montréal
# 220         1976.0   POINT (-73.7 45.53)  Montréal
# 226         1976.0  POINT (-73.93 45.42)  Montréal
# 234         2025.0   POINT (-73.58 45.5)  Montréal
# 239            NaN  POINT (-73.93 45.43)  Montréal
# 242            NaN  POINT (-73.55 45.48)  Montréal
# 245         2013.0  POINT (-73.75 45.47)  Montréal
# 246            NaN  POINT (-73.74 45.47)  Montréal
# 247            NaN  POINT (-73.55 45.63)  Montréal
# 248         1989.0  POINT (-73.55 45.57)  Montréal
# 249         1985.0   POINT (-73.62 45.5)  Montréal
# 250         1992.0  POINT (-73.57 45.52)  Montréal
# 251         1964.0  POINT (-73.63 45.47)  Montréal
# 252         1993.0   POINT (-73.58 45.5)  Montréal
# 253         1950.0  POINT (-73.69 45.54)  Montréal
# 268         1985.0   POINT (-73.8 45.47)  Montréal
# 270         1982.0   POINT (-73.75 45.5)  Montréal
# 275         2018.0    POINT (-73.5 45.7)  Montréal
# 286         1992.0  POINT (-73.93 45.43)  Montréal
# 311         2015.0   POINT (-73.85 45.5)  Montréal
# 330         1967.0  POINT (-73.67 45.52)  Montréal
# 396            NaN  POINT (-73.57 45.42)  Montréal
# 401            NaN  POINT (-73.93 45.43)  Montréal
# 412            NaN  POINT (-73.74 45.47)  Montréal
#
# [25 rows x 21 columns]

# %% [markdown]
# ### Creating a dictionary of the reference station to preprocess

# %%
tmp = []

for key in stn_id.keys():
    for id in stn_id[key]:

        lat = stns[stns['Climate ID'] == str(id)]['Latitude (Decimal Degrees)'].values[0]
        lon = stns[stns['Climate ID'] == str(id)]['Longitude (Decimal Degrees)'].values[0]

        admin = stns[stns['Climate ID'] == str(id)]['admin'].values[0]

        tmp.append({'Station': key, 
                    'Climate ID': id, 
                    'Latitude': lat, 
                    'Longitude': lon, 
                    'admin': admin})
        
ref_stn = pd.DataFrame(tmp)
ref_stn
# Out:
#                       Station Climate ID  Latitude  Longitude     admin
# 0  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 1  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal

# %% [markdown]
# ### Compute the distance from the stations to the reference stations

# %%
dist_stn_ref = []

for station, group in ref_stn.groupby(['Station']):

    tmp_stns = stns[stns['admin'].isin(group['admin'])]
    tmp_ref_stn = ref_stn[ref_stn['admin'].isin(group['admin'])]

    for index, ref in tmp_ref_stn.iterrows():
        for idx, stn in tmp_stns.iterrows() :

            if stn['Climate ID'] not in group['Climate ID'].values :
                ref_lat_lon = (ref['Latitude'], ref['Longitude'])
                stn_lat_lon = (stn['Latitude (Decimal Degrees)'], stn['Longitude (Decimal Degrees)'])
            
                dist = distance.distance(ref_lat_lon, stn_lat_lon).km

                dist_stn_ref.append({'Station' : ref['Station'],
                                     'Climate ID' : ref['Climate ID'],
                                     'Latitude': ref['Latitude'],
                                     'Longitude':  ref['Longitude'],
                                     'admin': admin,
                                     'Nearby Climate ID': stn['Climate ID'],
                                     'Distance (km)': dist
            })
            
            
dist_stn_ref = pd.DataFrame(dist_stn_ref)

dist_stn_ref
# Out:
#                        Station Climate ID  Latitude  Longitude     admin  \
# 0   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 1   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 2   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 3   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 4   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 5   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 6   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 7   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 8   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 9   Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 10  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 11  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 12  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 13  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 14  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 15  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 16  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 17  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 18  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 19  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 20  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 21  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 22  Montreal (McTavish/McGill)    7025280      45.5     -73.58  Montréal
# 23  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 24  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 25  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 26  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 27  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 28  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 29  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 30  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 31  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 32  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 33  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 34  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 35  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 36  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 37  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 38  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 39  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 40  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 41  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 42  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 43  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 44  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
# 45  Montreal (McTavish/McGill)    7024745      45.5     -73.58  Montréal
#
#    Nearby Climate ID  Distance (km)
# 0            7021945       8.966881
# 1            7024118       8.385239
# 2            7024256       9.951661
# 3            7024400      28.782395
# 4            7025000      28.456381
# 5            7025228       3.231210
# 6            7025250      13.702253
# 7            7025251      12.945362
# 8            7025252      14.637152
# 9            7025257       8.125190
# 10           7025260       3.126323
# 11           7025267       2.356193
# 12           7025270       5.137797
# 13           7025315       9.676092
# 14           7026073      17.519538
# 15           7026213      13.286868
# 16           7026612      23.088355
# 17           7026839      28.456381
# 18           7027280      21.102667
# 19           7027440       7.375893
# 20           702A9MD       8.925596
# 21           702FHL8      28.456381
# 22           702S006      12.945362
# 23           7021945       8.966881
# 24           7024118       8.385239
# 25           7024256       9.951661
# 26           7024400      28.782395
# 27           7025000      28.456381
# 28           7025228       3.231210
# 29           7025250      13.702253
# 30           7025251      12.945362
# 31           7025252      14.637152
# 32           7025257       8.125190
# 33           7025260       3.126323
# 34           7025267       2.356193
# 35           7025270       5.137797
# 36           7025315       9.676092
# 37           7026073      17.519538
# 38           7026213      13.286868
# 39           7026612      23.088355
# 40           7026839      28.456381
# 41           7027280      21.102667
# 42           7027440       7.375893
# 43           702A9MD       8.925596
# 44           702FHL8      28.456381
# 45           702S006      12.945362

# %% [markdown]
# ### Reading the data files of reference stations

# %%
df = pd.DataFrame()

for station, group in ref_stn.groupby(['Station']):

    for idx, ref in group.iterrows():
        start = int(stns[stns['Climate ID'] == ref['Climate ID']][f'{frequency} First Year'].values[0])
        end = int(stns[stns['Climate ID'] == ref['Climate ID']][f'{frequency} Last Year'].values[0])

        print(start, end)

        for year in list(range(start,end+1)):
            
            path = os.path.join(data_dir, f'*{ref['Climate ID']}_{year}*.csv')
            file = glob.glob(path)
            #print(file[0])
            data = pd.read_csv(file[0], encoding="ISO-8859-1")

            data.insert(0,'Station', ref['Station'])

            df = pd.concat([df, data])       
            
if frequency == 'DLY' :
    df['Date/Time'] = pd.to_datetime(df['Date/Time'])
    df.set_index('Date/Time', inplace=True)

if frequency == 'MLY' :
    #df['Date/Time'] = pd.to_datetime(df[['Year', 'Month']].assign(day=1)) 
    df['Date/Time'] = pd.to_datetime(df[['Year', 'Month']].assign(day=1)) + pd.offsets.MonthEnd(0)
    df.set_index('Date/Time', inplace=True)

    full_range = set(pd.date_range(start=df.index.min(), end =  df.index.max(), freq="ME"))
    full_range

    missing_dates = full_range.difference(set(df.index))

    missing_df = pd.DataFrame(index=list(missing_dates))

    missing_df['Climate ID'] = None 
    missing_df['Station'] = None 
    missing_df['Year'] = None
    missing_df['Month'] = None

    df = pd.concat([df, missing_df])

    df = df.sort_index()

    df['Station'] = df['Station'].ffill()
    df['Climate ID'] = df['Climate ID'].ffill()
    
    #df = df.asfreq('M')
    #df.index.freq = 'ME'
    #df = df.resample('ME').asfreq() 
    #new_range = pd.date_range(start=df['Date/Time'].min(), end =  df['Date/Time'].max(), freq="ME")
    
    #print(new_range)
    #df = df.set_index('Date/Time').reindex(new_range)
    #df = df.reindex(new_range)
    #df = df.asfreq('ME')
    
#df.set_index('Date/Time', inplace=True)

df['Climate ID'] = df['Climate ID'].ffill().astype(int).astype(str)

#df[(df['Year'] > 1991) & (df['Year'] < 1996)].asfreq('M')
df
# Out:
# 1871 1993
# 1994 2025
#                                Station  Longitude (x)  Latitude (y)  \
# Date/Time
# 1871-01-01  Montreal (McTavish/McGill)         -73.58          45.5
# 1871-01-02  Montreal (McTavish/McGill)         -73.58          45.5
# 1871-01-03  Montreal (McTavish/McGill)         -73.58          45.5
# 1871-01-04  Montreal (McTavish/McGill)         -73.58          45.5
# 1871-01-05  Montreal (McTavish/McGill)         -73.58          45.5
# ...                                ...            ...           ...
# 2025-12-27  Montreal (McTavish/McGill)         -73.58          45.5
# 2025-12-28  Montreal (McTavish/McGill)         -73.58          45.5
# 2025-12-29  Montreal (McTavish/McGill)         -73.58          45.5
# 2025-12-30  Montreal (McTavish/McGill)         -73.58          45.5
# 2025-12-31  Montreal (McTavish/McGill)         -73.58          45.5
#
#                Station Name Climate ID  Year  Month  Day  Data Quality  \
# Date/Time
# 1871-01-01  MONTREAL MCGILL    7025280  1871      1    1           NaN
# 1871-01-02  MONTREAL MCGILL    7025280  1871      1    2           NaN
# 1871-01-03  MONTREAL MCGILL    7025280  1871      1    3           NaN
# 1871-01-04  MONTREAL MCGILL    7025280  1871      1    4           NaN
# 1871-01-05  MONTREAL MCGILL    7025280  1871      1    5           NaN
# ...                     ...        ...   ...    ...  ...           ...
# 2025-12-27         MCTAVISH    7024745  2025     12   27           NaN
# 2025-12-28         MCTAVISH    7024745  2025     12   28           NaN
# 2025-12-29         MCTAVISH    7024745  2025     12   29           NaN
# 2025-12-30         MCTAVISH    7024745  2025     12   30           NaN
# 2025-12-31         MCTAVISH    7024745  2025     12   31           NaN
#
#             Max Temp (°C)  ... Total Snow (cm)  Total Snow Flag  \
# Date/Time                  ...
# 1871-01-01            NaN  ...             NaN              NaN
# 1871-01-02            NaN  ...             NaN              NaN
# 1871-01-03            NaN  ...             NaN              NaN
# 1871-01-04            NaN  ...             NaN              NaN
# 1871-01-05            NaN  ...             NaN              NaN
# ...                   ...  ...             ...              ...
# 2025-12-27            NaN  ...             NaN              NaN
# 2025-12-28            NaN  ...             NaN              NaN
# 2025-12-29            NaN  ...             NaN              NaN
# 2025-12-30            NaN  ...             NaN              NaN
# 2025-12-31            NaN  ...             NaN              NaN
#
#            Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# Date/Time
# 1871-01-01               NaN                NaN               NaN
# 1871-01-02               NaN                NaN               NaN
# 1871-01-03               NaN                NaN               NaN
# 1871-01-04               NaN                NaN               NaN
# 1871-01-05               NaN                NaN               NaN
# ...                      ...                ...               ...
# 2025-12-27               NaN                NaN               NaN
# 2025-12-28               NaN                NaN               NaN
# 2025-12-29               NaN                NaN               NaN
# 2025-12-30               NaN                NaN               NaN
# 2025-12-31               NaN                NaN               NaN
#
#             Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# Date/Time
# 1871-01-01                NaN                       NaN                   NaN
# 1871-01-02                NaN                       NaN                   NaN
# 1871-01-03                NaN                       NaN                   NaN
# 1871-01-04                NaN                       NaN                   NaN
# 1871-01-05                NaN                       NaN                   NaN
# ...                       ...                       ...                   ...
# 2025-12-27                NaN                       NaN                   NaN
# 2025-12-28                NaN                       NaN                   NaN
# 2025-12-29                NaN                       NaN                   NaN
# 2025-12-30                NaN                       NaN                   NaN
# 2025-12-31                NaN                       NaN                   NaN
#
#            Spd of Max Gust (km/h)  Spd of Max Gust Flag
# Date/Time
# 1871-01-01                    NaN                   NaN
# 1871-01-02                    NaN                   NaN
# 1871-01-03                    NaN                   NaN
# 1871-01-04                    NaN                   NaN
# 1871-01-05                    NaN                   NaN
# ...                           ...                   ...
# 2025-12-27                    NaN                   NaN
# 2025-12-28                    NaN                   NaN
# 2025-12-29                    NaN                   NaN
# 2025-12-30                    NaN                   NaN
# 2025-12-31                    NaN                   NaN
#
# [56613 rows x 31 columns]

# %% [markdown]
# ### Reading the data files of nearby stations

# %%
near_df = pd.DataFrame()

for station, group in dist_stn_ref.groupby(['Station']):

    for near in group['Nearby Climate ID'].unique():
        if  ~np.isnan(stns[stns['Climate ID'] == near][f'{frequency} First Year'].values[0]) :
            start = int(stns[stns['Climate ID'] == near][f'{frequency} First Year'].values[0])
            end = int(stns[stns['Climate ID'] == near][f'{frequency} Last Year'].values[0])

            print(start, end)

            for year in list(range(start,end+1)):
                path = os.path.join(data_dir, f'*{near}_{year}*.csv')
                file = glob.glob(path)
                #print(file[0])
                data = pd.read_csv(file[0], encoding="ISO-8859-1")

                near_df = pd.concat([near_df, data])      


if frequency == 'DLY' :
    near_df['Date/Time'] = pd.to_datetime(near_df['Date/Time'])

if frequency == 'MLY' :
    near_df['Date/Time'] = pd.to_datetime(near_df[['Year', 'Month']].assign(day=1)) + pd.offsets.MonthEnd(0)
    

near_df = near_df.dropna(subset=cols, how='all')

near_df = near_df.dropna(subset=[Tmax, Tmin, Tmean], how='any')

near_df['Climate ID'] = near_df['Climate ID'].astype(str)

near_df
# Out:
# 1960 1963
# 1973 1983
# 1965 1976
# 1906 1976
# 2017 2021
# 1941 2013
# 2013 2025
# 1994 2008
# 1948 1989
# 1956 1985
# 1971 1992
# 1964 1964
# 1948 1950
# 1973 1985
# 1973 1982
# 1973 2024
# 1969 1992
# 1952 2023
# 1931 1967
# 1993 2025
# 2002 2025
#      Longitude (x)  Latitude (y)                          Station Name  \
# 255         -73.67         45.45                           COTE ST LUC
# 256         -73.67         45.45                           COTE ST LUC
# 257         -73.67         45.45                           COTE ST LUC
# 258         -73.67         45.45                           COTE ST LUC
# 259         -73.67         45.45                           COTE ST LUC
# ..             ...           ...                                   ...
# 82          -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 83          -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 84          -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 85          -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 86          -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
#
#     Climate ID  Date/Time  Year  Month  Day  Data Quality  Max Temp (°C)  ...  \
# 255    7021945 1960-09-12  1960      9   12           NaN           15.6  ...
# 256    7021945 1960-09-13  1960      9   13           NaN           18.3  ...
# 257    7021945 1960-09-14  1960      9   14           NaN           17.2  ...
# 258    7021945 1960-09-15  1960      9   15           NaN           18.3  ...
# 259    7021945 1960-09-16  1960      9   16           NaN           16.7  ...
# ..         ...        ...   ...    ...  ...           ...            ...  ...
# 82     702S006 2025-03-24  2025      3   24           NaN            3.7  ...
# 83     702S006 2025-03-25  2025      3   25           NaN            4.4  ...
# 84     702S006 2025-03-26  2025      3   26           NaN            4.7  ...
# 85     702S006 2025-03-27  2025      3   27           NaN            7.7  ...
# 86     702S006 2025-03-28  2025      3   28           NaN            3.7  ...
#
#     Total Snow (cm)  Total Snow Flag Total Precip (mm)  Total Precip Flag  \
# 255             0.0              NaN              22.1                NaN
# 256             0.0              NaN               7.6                NaN
# 257             0.0              NaN               0.0                NaN
# 258             0.0              NaN               1.8                NaN
# 259             0.0              NaN               0.0                NaN
# ..              ...              ...               ...                ...
# 82              NaN              NaN               5.7                NaN
# 83              NaN              NaN               0.5                NaN
# 84              NaN              NaN               0.2                NaN
# 85              NaN              NaN               0.8                NaN
# 86              NaN              NaN               1.0                NaN
#
#     Snow on Grnd (cm)  Snow on Grnd Flag Dir of Max Gust (10s deg)  \
# 255               NaN                NaN                       NaN
# 256               NaN                NaN                       NaN
# 257               NaN                NaN                       NaN
# 258               NaN                NaN                       NaN
# 259               NaN                NaN                       NaN
# ..                ...                ...                       ...
# 82                0.0                NaN                      12.0
# 83                0.0                NaN                      26.0
# 84                0.0                NaN                      25.0
# 85                0.0                NaN                      25.0
# 86                0.0                NaN                      29.0
#
#      Dir of Max Gust Flag Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 255                   NaN                    NaN                   NaN
# 256                   NaN                    NaN                   NaN
# 257                   NaN                    NaN                   NaN
# 258                   NaN                    NaN                   NaN
# 259                   NaN                    NaN                   NaN
# ..                    ...                    ...                   ...
# 82                    NaN                   36.0                   NaN
# 83                    NaN                   38.0                   NaN
# 84                    NaN                   38.0                   NaN
# 85                    NaN                   48.0                   NaN
# 86                    NaN                   44.0                   NaN
#
# [179516 rows x 31 columns]

# %% [markdown]
# ### Looking for missing values

# %%
df.isna().sum()
# Out:
# Station                          0
# Longitude (x)                    0
# Latitude (y)                     0
# Station Name                     0
# Climate ID                       0
# Year                             0
# Month                            0
# Day                              0
# Data Quality                 56613
# Max Temp (°C)                 1969
# Max Temp Flag                56299
# Min Temp (°C)                 1935
# Min Temp Flag                56223
# Mean Temp (°C)                1987
# Mean Temp Flag               56287
# Heat Deg Days (°C)            1987
# Heat Deg Days Flag           56287
# Cool Deg Days (°C)            1987
# Cool Deg Days Flag           56287
# Total Rain (mm)              12373
# Total Rain Flag              45112
# Total Snow (cm)              12384
# Total Snow Flag              45519
# Total Precip (mm)             2311
# Total Precip Flag            50795
# Snow on Grnd (cm)            41653
# Snow on Grnd Flag            55487
# Dir of Max Gust (10s deg)    53781
# Dir of Max Gust Flag         56417
# Spd of Max Gust (km/h)       47969
# Spd of Max Gust Flag         56420
# dtype: int64

# %% [markdown]
# ### Finding min and max Date/Time of available data

# %%
tmp_avail = df.dropna(subset=cols, how='all')

start = tmp_avail.index.min()
end = tmp_avail.index.max()
end = '2025-03-28'

# %% [markdown]
# ### Replacing missing values for the temperatures with data from the nearest available stations

# %%
for name, group in df.groupby(['Station Name'], dropna=False):
    
    clim_id = group['Climate ID'].unique()

    start_stn = group.index.min()
    end_stn = group.index.max()

    tmp_period = df[(df.index >= start_stn) & (df.index <= end_stn)]

    tmp_period = tmp_period[(tmp_period[Tmax].isna()) | \
                            (tmp_period[Tmin].isna()) | \
                            (tmp_period[Tmean].isna())]
    
    for idx, row in tmp_period.iterrows() :

        tmp = near_df[near_df['Date/Time'] == pd.to_datetime(str(idx))]

        if len(tmp) == 0 :
            start = idx
        else :
            print(idx)
            near_idx = dist_stn_ref[(dist_stn_ref['Climate ID'].isin(clim_id)) & (dist_stn_ref['Nearby Climate ID'].isin(tmp['Climate ID'].values.astype(str)))]['Distance (km)'].idxmin()

            nearest = dist_stn_ref.loc[near_idx]['Nearby Climate ID']

            new_row = tmp[tmp['Climate ID'] == nearest]
            
            new_row.insert(0, 'Station', group['Station'].unique())
            print('new', new_row)

            df.loc[pd.to_datetime(idx)] = new_row.iloc[0]
# Out:
# 1994-01-01 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 0  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 0  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-01  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 0    1           NaN  ...              3.8             NaN                3.4
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 0               NaN               14.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 0                       22.0                  NaN                      44
#
#   Spd of Max Gust Flag
# 0                  NaN
#
# [1 rows x 32 columns]
# 1994-01-02 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 1  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 1  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-02  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 1    2           NaN  ...              0.2             NaN                0.2
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 1               NaN               15.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 1                       22.0                  NaN                      43
#
#   Spd of Max Gust Flag
# 1                  NaN
#
# [1 rows x 32 columns]
# 1994-01-03 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 2  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 2  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-03  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 2    3           NaN  ...              0.0             NaN                0.0
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 2               NaN               15.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 2                        4.0                  NaN                      32
#
#   Spd of Max Gust Flag
# 2                  NaN
#
# [1 rows x 32 columns]
# 1994-01-04 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 3  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 3  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-04  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 3    4           NaN  ...             24.8             NaN               24.8
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 3               NaN               15.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 3                        2.0                  NaN                      70
#
#   Spd of Max Gust Flag
# 3                  NaN
#
# [1 rows x 32 columns]
# 1994-01-05 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 4  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 4  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-05  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 4    5           NaN  ...              0.8             NaN                0.8
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 4               NaN               24.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 4                       25.0                  NaN                      48
#
#   Spd of Max Gust Flag
# 4                  NaN
#
# [1 rows x 32 columns]
# 1994-01-06 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 5  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 5  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-06  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 5    6           NaN  ...              0.0             NaN                0.0
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 5               NaN               20.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 5                       26.0                  NaN                      35
#
#   Spd of Max Gust Flag
# 5                  NaN
#
# [1 rows x 32 columns]
# 1994-01-07 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 6  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 6  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-07  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 6    7           NaN  ...              0.0               T                0.0
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 6                 T               19.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 6                        4.0                  NaN                      35
#
#   Spd of Max Gust Flag
# 6                  NaN
#
# [1 rows x 32 columns]
# 1994-01-08 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 7  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 7  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-08  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 7    8           NaN  ...              7.8             NaN                7.8
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 7               NaN               19.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 7                        4.0                  NaN                      39
#
#   Spd of Max Gust Flag
# 7                  NaN
#
# [1 rows x 32 columns]
# 1994-01-09 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 8  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 8  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-09  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 8    9           NaN  ...              0.4             NaN                0.4
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 8               NaN               20.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 8                       24.0                  NaN                      46
#
#   Spd of Max Gust Flag
# 8                  NaN
#
# [1 rows x 32 columns]
# 1994-01-10 00:00:00
# new                       Station  Longitude (x)  Latitude (y)  \
# 9  Montreal (McTavish/McGill)         -73.75         45.47
#
#                              Station Name Climate ID  Date/Time  Year  Month  \
# 9  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-10  1994      1
#
#    Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 9   10           NaN  ...              0.0             NaN                0.0
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 9               NaN               19.0               NaN
#
#    Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 9                       24.0                  NaN                      44
#
#   Spd of Max Gust Flag
# 9                  NaN
#
# [1 rows x 32 columns]
# 1994-01-11 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 10  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 10  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-11  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 10   11           NaN  ...              2.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 10                2.2               NaN               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 10                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 10                  NaN
#
# [1 rows x 32 columns]
# 1994-01-12 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 11  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 11  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-12  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 11   12           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 11                0.0               NaN               16.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 11                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 11                  NaN
#
# [1 rows x 32 columns]
# 1994-01-13 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 12  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 12  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-13  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 12   13           NaN  ...              0.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 12                0.4               NaN               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 12                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 12                  NaN
#
# [1 rows x 32 columns]
# 1994-01-14 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 13  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 13  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-14  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 13   14           NaN  ...              5.8             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 13                5.8               NaN               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 13                       18.0                  NaN                      33
#
#    Spd of Max Gust Flag
# 13                  NaN
#
# [1 rows x 32 columns]
# 1994-01-15 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 14  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 14  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-15  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 14   15           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 14                0.0                 T               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 14                       24.0                  NaN                      50
#
#    Spd of Max Gust Flag
# 14                  NaN
#
# [1 rows x 32 columns]
# 1994-01-16 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 15  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 15  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-16  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 15   16           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 15                0.0                 T               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 15                       24.0                  NaN                      41
#
#    Spd of Max Gust Flag
# 15                  NaN
#
# [1 rows x 32 columns]
# 1994-01-17 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 16  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 16  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-17  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 16   17           NaN  ...              8.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 16                8.4               NaN               16.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 16                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 16                  NaN
#
# [1 rows x 32 columns]
# 1994-01-18 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 17  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 17  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-18  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 17   18           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 17                0.0                 T               20.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 17                       29.0                  NaN                      41
#
#    Spd of Max Gust Flag
# 17                  NaN
#
# [1 rows x 32 columns]
# 1994-01-19 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 18  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 18  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-19  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 18   19           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 18                0.0               NaN               18.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 18                       26.0                  NaN                      37
#
#    Spd of Max Gust Flag
# 18                  NaN
#
# [1 rows x 32 columns]
# 1994-01-20 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 19  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 19  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-20  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 19   20           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 19                0.0                 T               18.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 19                       23.0                  NaN                      37
#
#    Spd of Max Gust Flag
# 19                  NaN
#
# [1 rows x 32 columns]
# 1994-01-21 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 20  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 20  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-21  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 20   21           NaN  ...              0.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 20                0.2               NaN               18.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 20                       23.0                  NaN                      44
#
#    Spd of Max Gust Flag
# 20                  NaN
#
# [1 rows x 32 columns]
# 1994-01-22 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 21  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 21  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-22  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 21   22           NaN  ...              0.6             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 21                0.6               NaN               16.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 21                       25.0                  NaN                      41
#
#    Spd of Max Gust Flag
# 21                  NaN
#
# [1 rows x 32 columns]
# 1994-01-23 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 22  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 22  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-23  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 22   23           NaN  ...              6.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 22                6.0               NaN               16.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 22                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 22                  NaN
#
# [1 rows x 32 columns]
# 1994-01-24 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 23  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 23  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-24  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 23   24           NaN  ...              2.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 23                2.2               NaN               21.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 23                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 23                  NaN
#
# [1 rows x 32 columns]
# 1994-01-25 00:00:00
#                        Station  Longitude (x)  Latitude (y)  \
# 24  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 24  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-25  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 24   25           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 24                0.0                 T               21.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 24                        2.0                  NaN                      39
#
#    Spd of Max Gust Flag
# 24                  NaN
#
# [1 rows x 32 columns]
# 1994-01-26 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 25  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 25  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-26  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 25   26           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 25                0.0               NaN               19.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 25                        2.0                  NaN                      43
#
#    Spd of Max Gust Flag
# 25                  NaN
#
# [1 rows x 32 columns]
# 1994-01-27 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 26  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 26  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-27  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 26   27           NaN  ...              3.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 26                3.4               NaN               17.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 26                       13.0                  NaN                      50
#
#    Spd of Max Gust Flag
# 26                  NaN
#
# [1 rows x 32 columns]
# 1994-01-28 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 27  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 27  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-28  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 27   28           NaN  ...              1.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 27               21.6               NaN               17.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 27                       22.0                  NaN                      69
#
#    Spd of Max Gust Flag
# 27                  NaN
#
# [1 rows x 32 columns]
# 1994-01-29 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 28  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 28  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-29  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 28   29           NaN  ...              0.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 28                0.6               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 28                       23.0                  NaN                      63
#
#    Spd of Max Gust Flag
# 28                  NaN
#
# [1 rows x 32 columns]
# 1994-01-30 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 29  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 29  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-30  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 29   30           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 29                0.0                 T               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 29                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 29                  NaN
#
# [1 rows x 32 columns]
# 1994-01-31 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 30  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 30  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-01-31  1994      1
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 30   31           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 30                0.0               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 30                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 30                  NaN
#
# [1 rows x 32 columns]
# 1994-02-01 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 31  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 31  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-01  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 31    1           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 31                0.0               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 31                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 31                  NaN
#
# [1 rows x 32 columns]
# 1994-02-02 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 32  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 32  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-02  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 32    2           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 32                0.0               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 32                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 32                  NaN
#
# [1 rows x 32 columns]
# 1994-02-03 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 33  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 33  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-03  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 33    3           NaN  ...              1.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 33                1.4               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 33                       25.0                  NaN                      41
#
#    Spd of Max Gust Flag
# 33                  NaN
#
# [1 rows x 32 columns]
# 1994-02-04 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 34  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 34  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-04  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 34    4           NaN  ...              0.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 34                0.2               NaN               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 34                       23.0                  NaN                      33
#
#    Spd of Max Gust Flag
# 34                  NaN
#
# [1 rows x 32 columns]
# 1994-02-05 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 35  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 35  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-05  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 35    5           NaN  ...              0.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 35                0.4               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 35                       24.0                  NaN                      54
#
#    Spd of Max Gust Flag
# 35                  NaN
#
# [1 rows x 32 columns]
# 1994-02-06 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 36  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 36  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-06  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 36    6           NaN  ...              0.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 36                0.4               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 36                       23.0                  NaN                      39
#
#    Spd of Max Gust Flag
# 36                  NaN
#
# [1 rows x 32 columns]
# 1994-02-07 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 37  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 37  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-07  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 37    7           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 37                0.0                 T               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 37                       26.0                  NaN                      46
#
#    Spd of Max Gust Flag
# 37                  NaN
#
# [1 rows x 32 columns]
# 1994-02-08 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 38  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 38  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-08  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 38    8           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 38                0.0                 T               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 38                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 38                  NaN
#
# [1 rows x 32 columns]
# 1994-02-09 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 39  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 39  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-09  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 39    9           NaN  ...              4.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 39                4.2               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 39                        4.0                  NaN                      33
#
#    Spd of Max Gust Flag
# 39                    E
#
# [1 rows x 32 columns]
# 1994-02-10 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 40  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 40  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-10  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 40   10           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 40                0.0                 T               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 40                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 40                  NaN
#
# [1 rows x 32 columns]
# 1994-02-11 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 41  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 41  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-11  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 41   11           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 41                0.0               NaN               13.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 41                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 41                  NaN
#
# [1 rows x 32 columns]
# 1994-02-12 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 42  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 42  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-12  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 42   12           NaN  ...              0.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 42                0.2               NaN               13.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 42                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 42                  NaN
#
# [1 rows x 32 columns]
# 1994-02-13 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 43  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 43  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-13  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 43   13           NaN  ...             14.8             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 43               14.6               NaN               20.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 43                       24.0                  NaN                      35
#
#    Spd of Max Gust Flag
# 43                  NaN
#
# [1 rows x 32 columns]
# 1994-02-14 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 44  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 44  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-14  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 44   14           NaN  ...              0.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 44                0.4               NaN               22.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 44                       25.0                  NaN                      46
#
#    Spd of Max Gust Flag
# 44                  NaN
#
# [1 rows x 32 columns]
# 1994-02-15 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 45  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 45  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-15  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 45   15           NaN  ...              5.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 45                4.4               NaN               15.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 45                        4.0                  NaN                      35
#
#    Spd of Max Gust Flag
# 45                  NaN
#
# [1 rows x 32 columns]
# 1994-02-16 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 46  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 46  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-16  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 46   16           NaN  ...              1.4             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 46                1.4               NaN               19.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 46                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 46                  NaN
#
# [1 rows x 32 columns]
# 1994-02-17 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 47  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-17  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 47   17           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 47                0.0               NaN               18.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 47                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 47                  NaN
#
# [1 rows x 32 columns]
# 1994-02-18 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 48  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 48  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-18  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 48   18           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 48                0.0               NaN               17.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 48                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 48                  NaN
#
# [1 rows x 32 columns]
# 1994-02-19 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 49  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 49  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-19  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 49   19           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 49                0.0                 T               17.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 49                        NaN                  NaN                     <31
#
#    Spd of Max Gust Flag
# 49                  NaN
#
# [1 rows x 32 columns]
# 1994-02-20 00:00:00
#                        Station  Longitude (x)  Latitude (y)  \
# 50  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 50  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-20  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 50   20           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 50                1.2               NaN               16.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 50                       22.0                  NaN                      37
#
#    Spd of Max Gust Flag
# 50                  NaN
#
# [1 rows x 32 columns]
# 1994-02-21 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 51  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 51  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-21  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 51   21           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 51                0.0               NaN                7.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 51                       23.0                  NaN                      32
#
#    Spd of Max Gust Flag
# 51                  NaN
#
# [1 rows x 32 columns]
# 1994-02-22 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 52  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 52  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-22  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 52   22           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 52                0.0                 T                5.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 52                       28.0                  NaN                      32
#
#    Spd of Max Gust Flag
# 52                  NaN
#
# [1 rows x 32 columns]
# 1994-02-23 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 53  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 53  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-23  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 53   23           NaN  ...             11.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 53               10.8               NaN                5.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 53                        4.0                  NaN                      41
#
#    Spd of Max Gust Flag
# 53                  NaN
#
# [1 rows x 32 columns]
# 1994-02-24 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 54  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 54  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-24  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 54   24           NaN  ...             27.8             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 54               24.6               NaN               14.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 54                        6.0                  NaN                      43
#
#    Spd of Max Gust Flag
# 54                  NaN
#
# [1 rows x 32 columns]
# 1994-02-25 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 55  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 55  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-25  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 55   25           NaN  ...              2.2             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 55                1.2               NaN               32.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 55                       25.0                  NaN                      48
#
#    Spd of Max Gust Flag
# 55                  NaN
#
# [1 rows x 32 columns]
# 1994-02-26 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 56  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 56  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-26  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 56   26           NaN  ...              0.0             NaN
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 56                0.0               NaN               17.0               NaN
#
#     Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 56                       24.0                  NaN                      46
#
#    Spd of Max Gust Flag
# 56                  NaN
#
# [1 rows x 32 columns]
# 1994-02-27 00:00:00
# new                        Station  Longitude (x)  Latitude (y)  \
# 57  Montreal (McTavish/McGill)         -73.75         45.47
#
#                               Station Name Climate ID  Date/Time  Year  Month  \
# 57  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1994-02-27  1994      2
#
#     Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 57   27           NaN  ...              0.0               T
#
#     Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# ...
# new                         Station  Longitude (x)  Latitude (y)  \
# 346  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 346  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-13  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 346     12   13           NaN  ...              0.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 346                0.0               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 346                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 346                  NaN
#
# [1 rows x 32 columns]
# 1993-12-14 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 347  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 347  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-14  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 347     12   14           NaN  ...              0.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 347                0.0               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 347                        3.0                  NaN                      37
#
#     Spd of Max Gust Flag
# 347                  NaN
#
# [1 rows x 32 columns]
# 1993-12-15 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 348  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 348  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-15  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 348     12   15           NaN  ...              0.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 348                0.0               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 348                        3.0                  NaN                      37
#
#     Spd of Max Gust Flag
# 348                  NaN
#
# [1 rows x 32 columns]
# 1993-12-16 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 349  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 349  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-16  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 349     12   16           NaN  ...              0.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 349                0.0               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 349                        2.0                  NaN                      41
#
#     Spd of Max Gust Flag
# 349                  NaN
#
# [1 rows x 32 columns]
# 1993-12-17 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 350  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 350  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-17  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 350     12   17           NaN  ...              0.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 350                0.0               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 350                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 350                  NaN
#
# [1 rows x 32 columns]
# 1993-12-18 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 351  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 351  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-18  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 351     12   18           NaN  ...              0.4             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 351                0.4               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 351                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 351                  NaN
#
# [1 rows x 32 columns]
# 1993-12-19 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 352  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 352  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-19  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 352     12   19           NaN  ...              0.0               T
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 352                0.0                 T                0.0                 T
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 352                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 352                  NaN
#
# [1 rows x 32 columns]
# 1993-12-20 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 353  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 353  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-20  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 353     12   20           NaN  ...              0.0               T
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 353                0.0                 T                0.0                 T
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 353                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 353                  NaN
#
# [1 rows x 32 columns]
# 1993-12-21 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 354  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 354  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-21  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 354     12   21           NaN  ...             26.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 354               26.2               NaN                0.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 354                        4.0                  NaN                      63
#
#     Spd of Max Gust Flag
# 354                  NaN
#
# [1 rows x 32 columns]
# 1993-12-22 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 355  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 355  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-22  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 355     12   22           NaN  ...              1.4             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 355                1.4               NaN               13.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 355                       25.0                  NaN                      65
#
#     Spd of Max Gust Flag
# 355                  NaN
#
# [1 rows x 32 columns]
# 1993-12-23 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 356  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 356  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-23  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 356     12   23           NaN  ...              0.0             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 356                0.0               NaN               13.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 356                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 356                  NaN
#
# [1 rows x 32 columns]
# 1993-12-24 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 357  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 357  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-24  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 357     12   24           NaN  ...              0.8             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 357                0.8               NaN               13.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 357                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 357                  NaN
#
# [1 rows x 32 columns]
# 1993-12-25 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 358  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 358  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-25  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 358     12   25           NaN  ...              0.4             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 358                0.4               NaN               14.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 358                       23.0                  NaN                      37
#
#     Spd of Max Gust Flag
# 358                  NaN
#
# [1 rows x 32 columns]
# 1993-12-26 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 359  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 359  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-26  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 359     12   26           NaN  ...              0.0               T
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 359                0.0                 T               14.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 359                       25.0                  NaN                      59
#
#     Spd of Max Gust Flag
# 359                  NaN
#
# [1 rows x 32 columns]
# 1993-12-27 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 360  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 360  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-27  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 360     12   27           NaN  ...              0.0               T
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 360                0.0                 T               13.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 360                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 360                  NaN
#
# [1 rows x 32 columns]
# 1993-12-28 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 361  Montreal (McTavish/McGill)          -73.5          45.7
#
#              Station Name Climate ID  Date/Time  Year  Month  Day  \
# 361  RIVIERE DES PRAIRIES    7026612 1993-12-28  1993     12   28
#
#      Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 361           NaN  ...              0.0             NaN                0.0
#
#     Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 361               NaN                NaN                 M
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 361                        NaN                  NaN                     NaN
#
#     Spd of Max Gust Flag
# 361                  NaN
#
# [1 rows x 32 columns]
# 1993-12-29 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 362  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 362  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-29  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 362     12   29           NaN  ...              1.4             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 362                1.4               NaN               13.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 362                        NaN                    M                     <31
#
#     Spd of Max Gust Flag
# 362                  NaN
#
# [1 rows x 32 columns]
# 1993-12-30 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 363  Montreal (McTavish/McGill)          -73.5          45.7
#
#              Station Name Climate ID  Date/Time  Year  Month  Day  \
# 363  RIVIERE DES PRAIRIES    7026612 1993-12-30  1993     12   30
#
#      Data Quality  ...  Total Snow (cm) Total Snow Flag  Total Precip (mm)  \
# 363           NaN  ...              0.0               T                0.0
#
#     Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 363                 T               23.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 363                        NaN                  NaN                     NaN
#
#     Spd of Max Gust Flag
# 363                  NaN
#
# [1 rows x 32 columns]
# 1993-12-31 00:00:00
# new                         Station  Longitude (x)  Latitude (y)  \
# 364  Montreal (McTavish/McGill)         -73.75         45.47
#
#                                Station Name Climate ID  Date/Time  Year  \
# 364  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    7025250 1993-12-31  1993
#
#      Month  Day  Data Quality  ...  Total Snow (cm) Total Snow Flag  \
# 364     12   31           NaN  ...              1.2             NaN
#
#      Total Precip (mm) Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 364                1.2               NaN               15.0               NaN
#
#      Dir of Max Gust (10s deg) Dir of Max Gust Flag  Spd of Max Gust (km/h)  \
# 364                       22.0                  NaN                      43
#
#     Spd of Max Gust Flag
# 364                  NaN
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Making sure that the temperature no longer has missing values

# %%
start
# Out:
# Timestamp('1891-10-21 00:00:00')

# %%
df[(df.index > start) & (df.index < end)].isna().sum()
# Out:
# Station                          0
# Longitude (x)                    0
# Latitude (y)                     0
# Station Name                     0
# Climate ID                       0
# Year                             0
# Month                            0
# Day                              0
# Data Quality                 48735
# Max Temp (°C)                    0
# Max Temp Flag                48650
# Min Temp (°C)                    0
# Min Temp Flag                48569
# Mean Temp (°C)                   0
# Mean Temp Flag               48642
# Heat Deg Days (°C)               0
# Heat Deg Days Flag           48642
# Cool Deg Days (°C)               0
# Cool Deg Days Flag           48642
# Total Rain (mm)              10549
# Total Rain Flag              37720
# Total Snow (cm)              10557
# Total Snow Flag              38046
# Total Precip (mm)              482
# Total Precip Flag            43631
# Snow on Grnd (cm)            32530
# Snow on Grnd Flag            47605
# Dir of Max Gust (10s deg)    45537
# Dir of Max Gust Flag         48436
# Spd of Max Gust (km/h)       39502
# Spd of Max Gust Flag         48564
# dtype: int64

# %% [markdown]
# ### Writing proceessed data to file

# %%
df[(df.index > start) & (df.index < end)].to_csv(outfile)
